# %%
# %%write_and_run CreateMatrix.py
#
# import pandas as pd
# import numpy as np
# from IPython.display import display
# import random
# from userclass import User
# from sklearn.model_selection import LeaveOneOut
# from Utils import recepten_bij_ingredient, ingredienten_bij_recept, recepten_bij_tag, tags_bij_recept, fillInMatrix, customUserDecoder
# import json
#
# ingredientsdf = pd.read_csv(f"/data/foodboost/ingredients.csv", index_col=0)
#
# #TRAIN_Matrix
# def generateTrainMatrix(Favorieten_Recepten, Columns, randomRecepten):
#
#     matrix = pd.DataFrame(columns = Columns)
#
#     for i in range(len(Favorieten_Recepten*2)):
#         matrix.loc[matrix.shape[0]] = 0
#
#     columnPrefix = "2-"
#     matrix2 = matrix.copy()
#     matrix2.columns = [columnPrefix + columnName for columnName in matrix2.columns]
#
#     X = np.array(Favorieten_Recepten)
#     loo = LeaveOneOut()
#     index_counter = 0
#
#     for train_index, test_index in loo.split(X):
#         X_train, X_test = X[train_index], X[test_index]
#
#         X_train_ingredient_unique = np.unique(np.concatenate([ingredienten_bij_recept(x) for x in X_train]))
#         X_test_ingredient_unique = np.unique(np.concatenate([ingredienten_bij_recept(x) for x in X_test]))
#
#         randomRecept = random.choice(randomRecepten)
#
#         #----- Matrix met train vullen
#         fillInMatrix(matrix, X_train_ingredient_unique, index_counter, True, False)
#
#         #Rij 1
#         fillInMatrix(matrix2, X_test_ingredient_unique, index_counter, False, False, columnPrefix = columnPrefix)
#         #print(matrix2)
#
#         #Rij 2
#         fillInMatrix(matrix2, ingredienten_bij_recept(randomRecept), index_counter+1, False, False, columnPrefix = columnPrefix)
#
#         #Put the value for the random tag as 1 and put y at 0, because it should be false
#         fillInMatrix(matrix2, 'y', index_counter, True, True)
#
#         #Show which random tag is taken and the one out
#         matrix2.loc[index_counter+1, 'Randomgerecht'] = randomRecept
#         matrix2.loc[index_counter, 'one out'] = X_test
#         matrix2.loc[index_counter+1, 'one out'] = X_test
#
#         index_counter += 2
#     return pd.concat([matrix, matrix2], axis=1)
#
#
# #TEST_Matrix
# def generateTestMatrix(Train_Favorieten, Test_Favorieten, Columns, randomRecepten):
#     matrix1 = pd.DataFrame(columns = Columns)
#     Recepten = np.array(Train_Favorieten)
#     Test_Recepten = np.array(Test_Favorieten)
#
#     for i in range(len(Test_Recepten)*2):
#         matrix1.loc[matrix1.shape[0]] = 0
#
#     matrix2 = matrix1.copy()
#     columnPrefix = "2-"
#     matrix2.columns = [columnPrefix + columnName for columnName in matrix2.columns]
#
#     #-----
#     for index_counter in range(len(Test_Recepten)):
#
#         Gerecht_Tags = np.unique(np.concatenate([ingredienten_bij_recept(x) for x in Recepten]))
#         Test_Gerecht_Tags = ingredienten_bij_recept(Test_Recepten[index_counter])
#
#         #----- Matrix1 met Userlist (80%) invullen
#         fillInMatrix(matrix1, Gerecht_Tags, index_counter, False, False)
#
#         #----- Matrix2 met Test_Favorieten (20%) vullen
#         fillInMatrix(matrix2, Test_Gerecht_Tags, index_counter, False, False, columnPrefix = columnPrefix)
#
#         #Put the y value as true
#         fillInMatrix(matrix2, 'y', index_counter, False, False)
#
#     for p in range(len(Test_Recepten), len(Test_Recepten)*2):
#         #----- Matrix1 met Userlist (80%) invullen
#         fillInMatrix(matrix1, Gerecht_Tags, p, False, False)
#
#         fillInMatrix(matrix2, ingredienten_bij_recept(random.choice(randomRecepten)), p, False, False, columnPrefix = columnPrefix)
#
#         #Put the y value as false
#         fillInMatrix(matrix2, 'y', p, False, False, fillInZero = True)
#     return pd.concat([matrix1, matrix2], axis=1)
#
# def getRandomRecipes(Tags, diner_recepten, compareToTags, UserTag = ""):
#     if (compareToTags):
#         TagRecipes = []
#         for Tag in Tags:
#             TagRecipes = np.concatenate((TagRecipes, recepten_bij_tag(Tag)))
#         #All recipes that belong to the list of tags that are also in diner recepten
#         return list(set(TagRecipes) & set(diner_recepten))
#     else:
#         #All diner recipes that are not in the user tag's recipes
#         return list(set(diner_recepten).difference(recepten_bij_tag(UserTag)))
#
# def createTrainMatrix(TrainUsers, Tags, diner_recepten, compareToTags = True):
#     Matrix = pd.DataFrame()
#     Columns = ingredientsdf[ingredientsdf['recipe'].isin(diner_recepten)].ingredient.unique()
#     if (compareToTags):
#         randomRecepten = getRandomRecipes(Tags, diner_recepten, compareToTags)
#         for user in TrainUsers:
#             TrainMatrix = generateTrainMatrix(
#                 user.Favorieten_Recepten[0],
#                 Columns,
#                 randomRecepten)
#             Matrix = pd.concat([Matrix, TrainMatrix], axis=0, ignore_index=True)
#     else:
#         for user in TrainUsers:
#             randomRecepten = getRandomRecipes(Tags, diner_recepten, compareToTags = False, UserTag = user.UserTag)
#             TrainMatrix = generateTrainMatrix(
#                 user.Favorieten_Recepten[0],
#                 Columns,
#                 randomRecepten)
#             Matrix = pd.concat([Matrix, TrainMatrix], axis=0, ignore_index=True)
#
#     return Matrix.fillna(0)
#
#
#
# def createValidateOrTestMatrix(ValidateUsers, Tags, diner_recepten, compareToTags = True):
#     Matrix = pd.DataFrame()
#     Columns = ingredientsdf[ingredientsdf['recipe'].isin(diner_recepten)].ingredient.unique()
#     if (compareToTags):
#         randomRecepten = getRandomRecipes(Tags, diner_recepten, compareToTags)
#         for user in ValidateUsers:
#             split = int(len(user.Favorieten_Recepten[0])*0.8)
#             ValidateMatrix = generateTestMatrix(
#                 user.Favorieten_Recepten[0][:split],
#                 user.Favorieten_Recepten[0][split:],
#                 Columns,
#                 randomRecepten)
#             Matrix = pd.concat([Matrix, ValidateMatrix], axis=0, ignore_index=True)
#     else:
#         for user in ValidateUsers:
#             split = int(len(user.Favorieten_Recepten[0])*0.8)
#             randomRecepten = getRandomRecipes(Tags, diner_recepten, compareToTags = False, UserTag = user.UserTag)
#             ValidateMatrix = generateTestMatrix(
#                 user.Favorieten_Recepten[0][:split],
#                 user.Favorieten_Recepten[0][split:],
#                 Columns,
#                 randomRecepten)
#             Matrix = pd.concat([Matrix, ValidateMatrix], axis=0, ignore_index=True)
#
#     return Matrix.fillna(0)
# Out:
# writing file CreateMatrix.py

# %%
# %store -r
getRandomRecipes(['hollands'], diner_recepten_bonno, False, UserTag = "italiaans")
# Out:
# ['Quiche met broccoli en gerookte zalm',
#  'Thaise roerbak met komkommer, cherrytomaten, ui, ananas en tofu',
#  'Indiase kippenpoten',
#  'Kruidencouscous en kipballetjes in saus',
#  'Gevulde kalkoen',
#  'Zoetzuur varkensvlees met bosui',
#  'Traybake met kip en mosterd',
#  'Gado gado noedelsalade ',
#  'Kip-pie met prei en Emmentaler',
#  'Mediterrane bonensalade met gerookte kip',
#  'Courgettegratin uit de oven met verse zalm en spinazie',
#  'Tuinbonenburger',
#  "Canard à l'orange",
#  'Ovendrumsticks met rodekoolcouscous',
#  'Tom kha kai',
#  'Oosterse groentesoep',
#  'Taco’s met kibbeling, rodekool &amp; alliolidressing',
#  'Volkoren mac and cheese met pompoen',
#  "Picadillo-tostada's met guacamole",
#  'Kleurrijke groentepasta met zoete aardappel',
#  'Thaise kipcurry met venkel',
#  'Traybake kip tandoori met kikkererwten en tomaat',
#  'Notenquiche',
#  'Kipchili',
#  'Groentetajine met couscous',
#  'Maaltijdsalade met avocadomayo',
#  'Gehakthachee met puree',
#  'Rendang Padang van Vanja van der Leeden',
#  'Aardappelomelet met tomaten',
#  'Visstoof met paprika, tomaat en krieltjes',
#  'Tarte tatin van sjalotten met marmelade',
#  'Pita gyros met tzatziki &amp; salade',
#  'Milde nasi goreng',
#  'Tajine met zoete aardappel, wortel en dadels',
#  'Groenteroerbak met tofu en zoete aardappel',
#  'Kantonese kip met aspergebroccoli',
#  'Frisse quiche met flame roasted zalm',
#  'Broodje barbecuebiefstuk',
#  'Vegetarische burger met friet',
#  'Vegetarische paella met gegrilde groenten en gebakken halloumi',
#  'Mediterrane visstoof met couscous',
#  'Asperge-erwtenfrittata met selderijolie',
#  'Volkorencouscous met geroosterde spitskool en tomatentapenade',
#  'Gewokte broccoli met garnalen',
#  'Karbonade in karnemelksaus',
#  'Italiaans gekruide vaderdag-burger met Vlaamse friet',
#  'Caesar tostada',
#  'Pasta met champignonsaus, kip en tuinerwten',
#  'Indiase korma met ei, spinazie &amp; bloemkoolrijst',
#  'Sushisoep',
#  'Salade van geroosterde groenten met kruiden en noten',
#  '10 minutennasi met ham en gebakken ei',
#  'Simpele kaasfondue',
#  'Pompoen-paprikastoof',
#  'Makreel van de BBQ',
#  'Varkensrollade met uiensaus',
#  'Snelle noedelroerbak met groene currypasta en een eitje',
#  'Hartige roerbak van biefstuk en paprika',
#  'Broodje gerookte wortel (sandwich smoked carrots)',
#  'Tortillaschotel met zoete aardappel, tomaat en avocado',
#  'Ovenschotel met krieltjes en broccoli',
#  'Russische bietenstamp met kool',
#  'Krieltjessalade met rivierkreeftjes &amp; romige bieslookmayo',
#  'Broodje verse roomkaas, gegrilde ham en ei',
#  'Aubergineschnitzels met mosterdsaus',
#  'Tagliatelle met tomatensaus, gebakken aubergine &amp; feta',
#  'Gele rijst met salami en puntpaprika ',
#  'Teriyakinoedels met gehakt &amp; sojabonen',
#  'Hollands stamppotje met rookworst',
#  'Franse kiprolletjes met spek en groenten',
#  "Vegan vistaco's",
#  'Nasi goreng met tempeh goreng in een slabakje',
#  'Kabeljauw met shoarmakruiden, venkel en broccolirijst',
#  'Orzo met kip en garnalen',
#  'Kerriekluifjes en bonen-kaassalade',
#  'Zalm met noedels, paksoi en sesam-limoendressing',
#  'Hartige winter-groentetaart',
#  'Gehaktballetjes, aardappel &amp; kool',
#  'Spruitjesstamppot met shoarma en knoflooksaus',
#  'Indiase groentecurry',
#  'Kipstoof in romige mosterdsaus',
#  'Flammkuchen met rauwkost en frisse tomatendip',
#  'Zalm met kastanjechampignons, paprika en linzen uit de oven',
#  'Maaltijdsalade van romaine, sperziebonen en garnalen',
#  'Gnocchiroerbak met spek &amp; courgette',
#  'Quiche bolognese ',
#  'Plaatpizza met tonijn en paprika',
#  'Pompoenstrudel met salie',
#  'Limburgs zuurvlees met ontbijtkoek',
#  'Gewokte biefstukpuntjes met groente en rijst',
#  'Hotdogbuffet met knakwortel',
#  'Ovenschotel met shoarma &amp; ei',
#  'Zalm met bladerdeeg en dillerijst',
#  'Andijviestamppot met zalm',
#  'Piri-piri drumsticks met wortel en aardappel',
#  'Picanha met rodewijnsaus en blauwe bessen',
#  'Kip en groenten uit de oven',
#  'Vegaschnitzel met salade van aardappel, broccoli &amp; dille',
#  'Soja-cashew-kipspiesjes met groene roerbak en rijst',
#  'Thaise noedelsalade met vegakip &amp; broccoli',
#  'Catalaanse worstspiesen met citroenmayonaise',
#  'Coq au vin van Donal Skehan',
#  'Ovenschotel met appel, spruiten en salami',
#  'Rodebiet-pastinaaksoep',
#  'Salade van makreel en bieten',
#  'Rijstsalade met omeletreepjes en basilicumolie',
#  'Chinese balletjes in zoetzure saus',
#  'Kip in zoetzure saus',
#  'Kruidige kipreepjes en hutspot met een pittige touch',
#  'Kabeljauw met linzen en salade',
#  'Frietje Vlaamse stoof',
#  "Daddy cool's fried chicken",
#  'Pompoenlasagne met pecannoten &amp; gorgonzolasaus',
#  'Witlofsalade met masaladressing',
#  'Spinazietaart met boerenkool, ricotta en tonijn',
#  'Rijstsalade met edamame bonen',
#  'Aziatische bloemkoolrijstbowl met rodekool &amp; spinazie',
#  'Ossenhaas wellington',
#  'Kalkoen met appel-salie-pecannotenvulling',
#  'Quinoasalade met gegrilde rodekool ',
#  'Pompoenlasagne met ricotta &amp; kalkoen',
#  "Thaise noedelsalade met kip &amp; pinda's",
#  'Rijkgevulde groentebowl met tonijn &amp; pittige dressing',
#  'Gebakken zalm met perfecte pofaardappel en dille-yoghurtsaus',
#  'Quinotto met garnalen, spinazie en knolselderij',
#  'Slavinken met gebakken mais &amp; aspergebroccoli',
#  'Gegrilde braadworst met bieten-koolrabisalade',
#  'Stoof van prei, tomaat, aardappel en ei',
#  'Ovenschotel met vegagehakt',
#  'Pad thai',
#  'Sobanoedelsoep met paddenstoelen en ei',
#  'Hertenrack met mosterd-pecankorst ',
#  'Linzen-tomatenstoof met bloemkool',
#  'Meatloaf met verstopte eieren',
#  'Kip tikka massala',
#  'Crunchy aardappelen met bospeen en spek',
#  'Karbonade van de grill met snijbonen en rode aardappel',
#  'Zalmpakketjes uit de oven met tuinerwtenpuree',
#  'Goudbruine broc\xadco\xadli\xad-to\xadnijn\xadtaart',
#  'Snelle quinoasalade met zalm in sojasaus',
#  'Filetlapjes met uienjus, aardappel-selderijpuree &amp; witlof',
#  'Prei-tuinerwtensoep met basilicum',
#  'Choripan',
#  'Italiaanse eendenborst met tomaatjes en lasagnette',
#  'Tunamelt-wraps',
#  'Ovenchili',
#  'Bloemkool uit de oven',
#  'Aardappel, pastinaak en biet met worst ',
#  'Vegan mealprep met pulled oats, zoete aardappel en pittige tomatensaus',
#  'Gevulde kalkoenfilets',
#  'Pilav van quinoa',
#  'Medaillons met paddenstoelen',
#  'Gwyneth Paltrows linzensalade ',
#  'Gegratineerde zuurkoolschotel',
#  "Taco's met kruidige zalmfilet en avocado",
#  'Gevulde courgette met worst en ui',
#  'Broodje gado gado',
#  'Kruidenquiche met ham en prei',
#  'Mexicaanse burger met rodekool &amp; ananassalsa',
#  'Courgettespaghetti met worstjes',
#  'Kerrierijstschotel met groenten en Alaska zalm',
#  'Komkommer-radijsgazpacho',
#  'Gestoofde kalfswangen met appel en amandelschaafsel',
#  'Wraps met shoarma en salade',
#  'Verse tomatensoep met tortillapizza',
#  'Wortel-gehaktballetjes met rijst en sperziebonen',
#  'Rucolastamppot met gerookte makreel',
#  'Kippastei met Parmezaankorst',
#  'Visragout met rijst en groente',
#  'Bonenstoof met aubergine en olijven',
#  'Maaltijdsalade met biefstukpuntjes',
#  'Slowcooker kip met citroen en rozemarijn',
#  'Curry van mungbonen',
#  'Brocollirijstbowl met zalm en avocadosaus',
#  'In bockbier gestoofde kippenpoten',
#  'Preitaart met oude kaas en pistachedeeg',
#  'Pittige kip met paksoi en noedels',
#  'Steak de boeuf met Franse roerbakgroente',
#  'Varkenshaas met witlof-druivensalade',
#  'Thaise visballetjes met noedelsoep',
#  'Fazant in cider met salie, bacon en appel',
#  "Samosa's met linzencurry",
#  'Noedelsalade met mango en garnalen',
#  'Lauwwarme soba noedels met sugarsnaps, paprika &amp; zalm',
#  'Massaman curry',
#  'Stamppot met andijvie, vegaballetjes &amp; Amsterdamse-uienjus',
#  'Geroosterde broccoli met zoete aardappel en worst',
#  'Mexicaanse wraps met kip en mais',
#  'Stoere chili',
#  'Vegetarische lenteminestrone',
#  'Kroketjes van heekbrandade',
#  'Bietenpizza met paddenstoelen, Franse kaas en gebakken ei',
#  'Zalmfilet op de huid met lauwwarme krieltjessalade',
#  'Entrecote met gekaramelliseerde ui en tijm',
#  'Marokkaanse pompoentajine met kikkererwten',
#  'Filodeegpakketjes met wokgroente',
#  'Pittige roerbak van biefstuk met rodekoolsalade &amp; rijst',
#  ' Zalmspies met sojaglaze van de BBQ',
#  'Gemarineerde zalm en botersla',
#  'Vietnamese karamelzalm van Donal Skehan',
#  'Indiaas gekruide kabeljauw en zoete-aardappelpuree met linzen',
#  'Zalm met waterkers-erwtenpuree',
#  'Mac and cheese met groente van Jamie Oliver',
#  'Quiche met twee soorten zalm',
#  'Kip picadillo met korianderroom',
#  'Broodje Aziatische visburger met sla',
#  'Kalkoen Hawaï met sugarsnaps',
#  'Vogelnestje',
#  'Varkensoester met wortels en salsa verde',
#  'Koolraapquiche met gerookte kip',
#  'Miniquiches met truffelbrie',
#  'Kip Stroganoff ',
#  "Paprika's met bonenvulling",
#  'Wraps met kipfilethaasjes',
#  'Rijstsalade met kruiden, tonijn en pistachenoten',
#  'Couscous met pittige garnalen',
#  'Makkelijke gevulde paprika’s met tuna melt',
#  'Mihoen met garnalen',
#  'Couscous met Thaise groenten en curryburger',
#  'Lasagne met gruyere en bechamelsaus',
#  'Hertenbiefstuk met specerijen-portsaus',
#  'Salade met quinoa, edamame en rosbief',
#  'Homemade vissticks',
#  'Saté met sambalboontjes en katjang pedis',
#  'Thaise kipnoedels met aubergine',
#  'Pasta met pompoen en walnoten-knoflookkruim',
#  'Mexicaanse wraps met groente en gegrilde biefstuk',
#  'Vegan curry van gestoofde groenten met naan',
#  'Runderstoof',
#  'Penne met ham en verstopte groente',
#  'Vegaburger met zoete-aardappelfriet &amp; rauwkostsalade',
#  'Burgers met rode-uienjam',
#  'Ravioli met rodekool, rauwe ham en rucola',
#  'Gebakken schol met krieltjes en wortelpeterselie',
#  'Traybake van kip met broccoli en zoete aardappel',
#  'Woknoedels met gember, groente en kip',
#  "Maaltijdsoep van geroosterde puntpaprika's",
#  'Mosselen in spicy tomatensaus',
#  'Geroosterde asperges &amp; chorizo',
#  'Kokosrijst met chiligarnalen',
#  'Ribkarbonade met geurige salie en rodekoolsalade',
#  'Gepofte Opperdoezers met bietjes en geitenkaas',
#  'Rijkgevulde Libanese salade falafel met hummus',
#  'Bruine bollen met ragout',
#  'Pitabroodje met pompoentajine en falafel',
#  'Gepofte aardappelen met viskoekjes',
#  'Kruidencouscous met gegrilde asperges',
#  'Bami met zoete puntpaprika',
#  'Asperges met ei-peterselieboter, krieltjes en pastrami',
#  'Lamsschenkels met bokbier',
#  'Pompoensoep met bloemkool &amp; naanbrood',
#  'Zomerse chili con carne',
#  'Quinoasalade',
#  'Preirösti &amp; frisse sla met kip en noten',
#  'Aardappelen à la niçoise',
#  'Pasta met zwarte bonen',
#  'Minikrieltjes met salami &amp; broccolisalade',
#  'Ramen (geïnspireerd op tonkotsu)',
#  'Zalmburger met coleslaw',
#  'Toast met gerookte zalm',
#  'Regenboogwortels met aardappel en speklapjes uit de oven',
#  'American burger met coleslaw',
#  'Aardappelgratin en witlof-bietensalade met runderworst',
#  'Broodje visstick met koolsalade',
#  'Alain Carons kip met mosterd-gembersaus, pilav rijst en gestoofde prei',
#  'BBQ steak sandwich van Jord Althuizen',
#  'Couscous met gebakken rodekool',
#  'Poriyal (Indiaas gebakken groenten) ',
#  'Gevulde paprika met kikkererwten, amandelen en geitenkaas',
#  'Fish and chips',
#  'Geroosterde aubergine met linzen &amp; komkommercouscous',
#  'Mexicaanse wraps met gegrilde kip en avocado',
#  'Groenteplaattaart met rauwe ham',
#  'Gevulde pompoen met cranberry en pecannoten',
#  "'Nasi' met pindasaus en vegan kipstuckjes ",
#  'Zoete sojawokschotel',
#  'Rodekool met appel en worstjes',
#  'In bietensap gemarineerde zalm',
#  'Gevulde varkensrollade uit de oven',
#  'Biefstuk met balsamico-honingsaus',
#  'Snelle paprikastoof met runderreepjes en rijst',
#  'Mosterdpuree met witlof uit de oven',
#  'Huts\xadpot met brui\xadne bo\xadnen',
#  'Jambalaya met chorizo en kip',
#  'Drie-kolenstoof met zoetzure ui en een magere gehaktbal',
#  'Varkenshaas met rijst en mango',
#  'Roerbak met Thaise kip, rijst &amp; homemade satésaus',
#  'Panpizza met witte kaas en wortelsalade',
#  'Gegrilde varkenshaasspiesen met couscous &amp; witte-kaasdip',
#  'Speltwrap met quinoa en zwartebonen-knoflookspread',
#  'Macaroni en ham',
#  'Vegetarische ramen met kurkuma en cavolo nero',
#  'Krokante vis met gele en rode friet',
#  'Zalmcurry met korianderrijst',
#  'Eenpansgerecht met rijst, paksoi en zalm',
#  'Spaghetti met avocado-tuinbonensaus en spekjes',
#  'Boerenkoolstamppot met pastinaak en een gehaktbal',
#  "Broccolicouscous met spinazie-kaasrondo's",
#  'Lasagne met champignons, tomaat en mozzarella',
#  'Hamburgers',
#  'Omeletmuffins met witlofsalade ',
#  'Tomaten met vegagehakt',
#  'Kruidenfusilli met kabeljauw en groenten uit de oven',
#  'Aziatische zalm en aspergebroccoli uit de oven',
#  "Vegan tortilla's met tofugehakt",
#  'Vega gehakt van tofu met mie en paksoi',
#  'Gegrilde zalm met wortelsalade &amp; bieslookkrieltjes',
#  'Gebakken gnocchi met gegrilde groenten',
#  'Vega sushi maki',
#  'Quiche met Leidse boerenkaas',
#  'Ovenschotel bloemkool &amp; kaas',
#  'Lauwwarme kriel-artisjoksalade',
#  'Zwartebonen-rijstsalade met avocado &amp; witte kaas',
#  'Vegaschnitzel met gegrilde mais en bakaardappeltjes',
#  'Noedelsoep met biefstuk, groenten en gekookt ei',
#  'Winterpeensoep met geitenkaassaus',
#  "Geroosterde 'pekingkip' met hoisinsaus",
#  'Vegaburger met aardappel en wortelsalade',
#  'Stevige kippensoep',
#  'Perzische yoghurtsoep',
#  'Kerriezuurkool-stamppot',
#  'Prei-slastamppot met zoete aardappel en verse worst',
#  'Vietnamese noedelsalade met gemarineerde garnalen',
#  'Gegrilde karbonades met sperziebonen',
#  'Hollandse kabeljauwburger met augurkensalsa en salade',
#  'Gekruide kabeljauw en verse pappardelle',
#  'Spinaziecurry',
#  'Oosterse kip met spruitjes en witte kool',
#  'Zuurkoolschotel met sappige karbonade en appel',
#  'Lekkerbekjes met mosterdsaus',
#  'Crispy kabeljauw met kleurige rijst en komkommerdip',
#  'Aardappelsalade met tonijn',
#  'Smeuiige paella met kip',
#  'Hele kip met srirachamayo',
#  'Snijbietsalade met chaource ',
#  'Vegetarische Bratwurst met krieltjes &amp; bloemkool',
#  'Kip Jambalaya',
#  'Warmgerookte zalm in honing-sojamarinade',
#  'Ovenpasta met tartaarballetjes, prei en ricotta',
#  'Wortelgratin',
#  'Hachee van Nicky',
#  'Noedelsalade met dragondressing',
#  'Macaroni lesco',
#  'Kipragout met kastanjechampignons &amp; broccolirijst',
#  'Schorseneren met ham en ei',
#  'Herfstminestrone',
#  'Driekazenfondue',
#  'Vegapie met vegagehakt',
#  'Runderkebab met yoghurtdip &amp; courgette-kaneelcouscous',
#  'Aziatische pastasalade met lichtpittige kip &amp; broccoli',
#  "Quiche 'caprese'",
#  'Pompoenlasagne met pastinaak &amp; bloemkool',
#  'Geurige maaltijdsoep met rijst en een eitje',
#  'Gadogado met krieltjes, homemade pindasaus en gebakken ei',
#  'Miesalade met aspergebroccoli, omelet en pittige sojadressing',
#  'Spicy ribkarbonade met mangochutney',
#  'Groente-bonensoep met garnalen',
#  'Frittata-soufflé met zoete aardappel',
#  'Groene minestrone met Parmezaanse kaas',
#  'Gele linzencurry',
#  'Tunesische shakshuka met gehaktballetjes',
#  'Groenteburger met rozemarijnaardappeltjes',
#  'Pappardelle met bloemkool &amp; taleggio',
#  'Noedelsalade met rundergehakt, groenten en pindakaasdressing',
#  'Volkorenlasagne met spinazie en linzen',
#  'Zeewierviskoekjes met quinoa-groenteroerbak',
#  'Rijst met kerriebloemkool en gebakken makreel',
#  'Traybake met lamsworstjes en pompoen',
#  'Ovenfrittata met wintergroenten',
#  'Broodje kabeljauwburger met mangochutney',
#  'Winterse uiensoep met Leffe Bruin',
#  'Plaattaart met gegrilde groenten',
#  'Spruitjesgratin met gehakt',
#  'Hertenbief met paddenstoelen en pastinaakpuree',
#  'Gevulde portobello met ricotta &amp; risotto',
#  'Flatbreads met gebakken zwarte bonen, gekruide bloemkool en hummus',
#  'Couscoussalade met feta, kipgehakt en bospeen',
#  'Salade met mungbonen en groene asperges',
#  'Lamskoteletten &amp; haricotsvertssalade',
#  'Chicken curry madras',
#  'Vegaschnitzel met paddenstoelen',
#  'Veldslastamppot met wortel, salade-ui en gehaktballetjes',
#  'Biefstuksalade met avocado-chimichurridressing',
#  'Taco’s met gehakt, kidneybonen en guacamole',
#  'Romige pasta vegakip met Italiaanse roerbakgroente',
#  'Zomerstamppot &amp; zoete spekjes',
#  'Broccoli-zalmschotel ',
#  'Indiase gehaktballetjes',
#  'Worstjes met uienjus',
#  'Honing-mosterd speklapjes',
#  'Krokante speklapjes en wokgroente met zoetzure saus',
#  'Camping kedgeree']
